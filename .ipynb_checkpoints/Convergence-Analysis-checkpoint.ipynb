# %%
import numpy as np
import matplotlib.pyplot as plt
# import os
# path_home = os.path.abspath(os.getcwd())
plt.style.use("/Users/abhi/Work/Projects/Hyperbolitcity-Gravitational-Collapse/Paper/Data/science.mplstyle")

with open("./4h/output.out", "r") as f:
    
    for line in f:
        if line.startswith("nt = "):
            nt_4h = int(line[4:])
        elif line.startswith("t_save_steps = "):
            tss_4h = int(line[len("t_save_steps = "):])
        elif line.startswith("dt = "):
            dt_4h = float(line[len("dt = "):])

    ts_array = (np.arange(0,nt_4h,1)[0::tss_4h])*dt_4h
            
ncc_in_4h = np.genfromtxt("./{}/ncc_in.dat".format("4h"), dtype = float, delimiter = ",")
ncc_out_4h = np.genfromtxt("./{}/ncc_out.dat".format("4h"), dtype = float, delimiter = ",")
res_4h = np.genfromtxt("./{}/e_rr_res.dat".format("4h"), dtype=float, delimiter=",")
phi_4h = np.genfromtxt("./{}/phi.dat".format("4h"), dtype=float, delimiter=",")
x_4h = np.genfromtxt("./{}/x.dat".format("4h"), dtype=float, delimiter=",")
ss_4h = np.genfromtxt("./{}/shift.dat".format("4h"), dtype = float, delimiter = ",")
r_4h = np.genfromtxt("./{}/r.dat".format("4h"), dtype = float, delimiter = ",")
exci_4h = np.genfromtxt("./{}/exci.dat".format("4h"), dtype = int, delimiter = " ")
ah_4h = np.genfromtxt("./{}/ah.dat".format("4h"), dtype = int, delimiter = " ")
nn_4h = np.genfromtxt("./{}/lapse.dat".format("4h"), dtype = float, delimiter = ",")
p_4h = np.genfromtxt("./{}/dt_phi.dat".format("4h"), dtype=float, delimiter=",")
q_4h = np.genfromtxt("./{}/dr_phi.dat".format("4h"), dtype=float, delimiter=",")
dt_phi_4h = (p_4h + ss_4h*q_4h)*nn_4h

ncc_in_2h = np.genfromtxt("./{}/ncc_in.dat".format("2h"), dtype = float, delimiter = ",")
ncc_out_2h = np.genfromtxt("./{}/ncc_out.dat".format("2h"), dtype = float, delimiter = ",")
res_2h = np.genfromtxt("./{}/e_rr_res.dat".format("2h"), dtype=float, delimiter=",")
phi_2h = np.genfromtxt("./{}/phi.dat".format("2h"), dtype=float, delimiter=",")
x_2h = np.genfromtxt("./{}/x.dat".format("2h"), dtype=float, delimiter=",")
ss_2h = np.genfromtxt("./{}/shift.dat".format("2h"), dtype = float, delimiter = ",")
r_2h = np.genfromtxt("./{}/r.dat".format("2h"), dtype = float, delimiter = ",")
exci_2h = np.genfromtxt("./{}/exci.dat".format("2h"), dtype = int, delimiter = " ")
ah_2h = np.genfromtxt("./{}/ah.dat".format("2h"), dtype = int, delimiter = " ")
nn_2h = np.genfromtxt("./{}/lapse.dat".format("2h"), dtype = float, delimiter = ",")
p_2h = np.genfromtxt("./{}/dt_phi.dat".format("2h"), dtype=float, delimiter=",")
q_2h = np.genfromtxt("./{}/dr_phi.dat".format("2h"), dtype=float, delimiter=",")
dt_phi_2h = (p_2h + ss_2h*q_2h)*nn_2h

# %%
ncc_in_h = np.genfromtxt("./{}/ncc_in.dat".format("h"), dtype = float, delimiter = ",")
ncc_out_h = np.genfromtxt("./{}/ncc_out.dat".format("h"), dtype = float, delimiter = ",")
res_h = np.genfromtxt("./{}/e_rr_res.dat".format("h"), dtype=float, delimiter=",")
phi_h = np.genfromtxt("./{}/phi.dat".format("h"), dtype=float, delimiter=",")
x_h = np.genfromtxt("./{}/x.dat".format("h"), dtype=float, delimiter=",")
ss_h = np.genfromtxt("./{}/shift.dat".format("h"), dtype = float, delimiter = ",")
r_h = np.genfromtxt("./{}/r.dat".format("h"), dtype = float, delimiter = ",")
exci_h = np.genfromtxt("./{}/exci.dat".format("h"), dtype = int, delimiter = " ")
ah_h = np.genfromtxt("./{}/ah.dat".format("h"), dtype = int, delimiter = " ")
nn_h = np.genfromtxt("./{}/lapse.dat".format("h"), dtype = float, delimiter = ",")
p_h = np.genfromtxt("./{}/dt_phi.dat".format("h"), dtype=float, delimiter=",")
q_h = np.genfromtxt("./{}/dr_phi.dat".format("h"), dtype=float, delimiter=",")
dt_phi_h = (p_h + ss_h*q_h)*nn_h

# %%
# l=10
# cp = 2
# cp1 = cp**2
# plt.plot(x_4h[ah_4h[l]:],np.log2(np.abs(res_4h[l][ah_4h[l]:])),label = '$4h$')
# plt.plot(x_2h[ah_2h[l]:],np.log2(cp*np.abs(res_2h[l][ah_2h[l]:])), label = r'$2h \,\times\, {}$'.format(cp))
# plt.plot(x_h[ah_h[l]:],np.log2(cp1*np.abs(res_h[l][ah_h[l]:])),label = r'$h \, \times \, {}$'.format(cp1))
# plt.legend()
# # plt.yscale('log')

# %%
# def get_l2_norm(arr,rad):
#     r_arr = np.zeros(len(arr))
#     for j in range(len(arr)):
#         a1 = arr[j][rad[j]:]
#         r_arr[j] = (np.sum(a1**2)/len(a1))*100
#     return (r_arr)**(1/2)

# res_4h_t = get_l2_norm(res_4h,exci_4h)
# res_2h_t = get_l2_norm(res_2h,exci_2h)
# res_h_t = get_l2_norm(res_h,exci_h)
#cp1 = 2
#cp2 = cp1**2
# plt.plot(ts_array[:len(res_4h_t)],np.log2(res_4h_t),label = "Low-resolution")
# plt.plot(ts_array[:len(res_2h_t)],np.log2(cp1*res_2h_t),label = r"Medium-resolution $\times \, {}$".format(cp1))
# plt.plot(ts_array[:len(res_h_t)],np.log2(cp2*res_h_t),label = r"High-resolution $\times \, {}$".format(cp2))
# # plt.yscale('log')
# plt.ylabel(r"$\log_2\left(\left\lVert E_{rr} \right\rVert_{2}\right)$")
# plt.xlabel("$t$")
# plt.legend()
# plt.tight_layout()
# #plt.savefig("/Users/abhi/Work/Projects/Hyperbolitcity-Gravitational-Collapse/Paper/Data/Convergence-Tests/RS-1/res_RS1.pdf")
# plt.show()

# %%
# def get_MS_mass_arr(arr,rad):
#     pos = int(0.75*len(arr[0]))
#     r_arr = np.zeros(len(arr))
#     for j in range(len(arr)):
#         r_arr[j] = 0.5*rad[pos]*((arr[j][pos])**2)
        
#     return r_arr

# MS_mass_4h = get_MS_mass_arr(ss_4h,r_4h)
# MS_mass_2h = get_MS_mass_arr(ss_2h,r_2h)
# MS_mass_h = get_MS_mass_arr(ss_h,r_h)

# %%
# l1 = np.min(np.array([len(MS_mass_4h),len(MS_mass_2h),len(ts_array)]))
# l2 = np.min(np.array([len(MS_mass_h),len(MS_mass_2h),len(ts_array)]))
# cp = 4
# plt.plot(ts_array[:l1],np.abs(MS_mass_4h[:l1] - MS_mass_2h[:l1]),label = r"$|\mathrm{low} - \mathrm{med}|$")
# plt.plot(ts_array[:l2],cp*np.abs(MS_mass_2h[:l2] - MS_mass_h[:l2]),label = r"$|\mathrm{med} - \mathrm{high}|\, \times $" + r"\,{}".format(cp))
# plt.xlabel("$t$")
# plt.ylabel("$\Delta M_{\mathrm{MS}}$")
# plt.legend()
# #plt.savefig("/Users/abhi/Work/Projects/Hyperbolitcity-Gravitational-Collapse/Paper/Data/Convergence-Tests/RS-1/MS_diff_RS1.pdf")
# plt.show()

# %%
# l = 30
# cp = 1
# plt.plot(x_4h[exci_4h[l]+2:], np.abs(nn_4h[l] - nn_2h[l][1:][0::2])[exci_4h[l]+2:], label = r'$\left|\phi_{\mathrm{low}} - \phi_{\mathrm{med}} \right|$')
# plt.plot(x_4h[exci_4h[l]+2:], cp*(np.abs(nn_2h[l][1:][0::2] - nn_h[l][3:][0::4])[exci_4h[l]+2:]), label = r'$\left|\phi_{\mathrm{med}} - \phi_{\mathrm{high}} \right|\times\,$' +"{}".format(cp))
# plt.legend()
# plt.xlabel('$x$')
# plt.tight_layout()
# plt.yscale('log')
# #plt.savefig("/Users/abhi/Work/Projects/Hyperbolitcity-Gravitational-Collapse/Paper/Data/Convergence-Tests/RS-1/phi_diff_RS1.pdf")
# plt.show()

# %%
# def l2norm(arr):
#     ar = arr[2:-3]
#     return (np.sum(ar**2)/len(ar))**(1/2)

# def get_cp(arrh,arrmed,arrlow):
#     length = np.min(np.array([len(arrh),len(arrmed),len(arrlow),len(ts_array)]))
# #     print(length)
#     cpnum = np.zeros(length-1)
#     cpdenom = np.zeros(length-1)
#     for j in range(length-1):
        
#         cpnum[j] = l2norm(np.abs((arrlow[j] - arrmed[j][1:][0::2])[exci_4h[j]:]))
#         cpdenom[j] = l2norm(np.abs((arrmed[j][1:][0::2] - arrh[j][3:][0::4])[exci_4h[j]:]))
    
#     return ts_array[1:length], np.log2(cpnum/cpdenom)

# %%
# time,cp_nn = get_cp(nn_h,nn_2h,nn_4h)
# time,cp_ss = get_cp(ss_h,ss_2h,ss_4h)
# time,cp_p = get_cp(p_h,p_2h,p_4h)
# time,cp_q = get_cp(q_h,q_2h,q_4h)
# time,cp_phi = get_cp(phi_h,phi_2h,phi_4h)

# plt.plot(time,cp_nn,label = r"$c(\alpha)$")
# plt.plot(time,cp_ss,label = r"$c(\zeta)$")
# plt.plot(time,cp_p,label = r"$c(p)$")
# plt.plot(time,cp_q,label = r"$c(q)$")
# plt.plot(time,cp_phi,label = r"$c(\phi)$")
# plt.ylim(1,6)
# plt.legend()
